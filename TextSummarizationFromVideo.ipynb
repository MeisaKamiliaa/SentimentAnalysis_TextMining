# %%
import pandas as pd
import numpy as np
from transformers import BartTokenizer, BartForConditionalGeneration

# %%
raw_text = pd.read_csv('C:/Users/Kayla/Documents/kuliah/Semester 5/Text Mining/Data/rawtext.tsv', sep='\t')
raw_text
# Out:
#                                                 title  \
# 0     Coursera Review Our Experience and How it Works
# 1   Coursera Review  My Thoughts After 5 Years and...
# 2   Top 5 Online Learning Platforms 2024  Review o...
# 3             Coursera Review The Best Elearning Site
# 4   Palo Alto Networks Cybersecurity Professional ...
# 5   ONLY UNSPONSORED Review of the Google Cybersec...
# 6   Coursera Review Why Is It the Best Online Lear...
# 7   Coursera Plus 2023 Review 7000 Online Courses ...
# 8          Coursera Review  Best Platform for Courses
# 9   Microsoft UX Design Professional Certificate R...
# 10  Meta Data Analyst Professional Certificate Rev...
# 11  Microsoft Business Analyst Professional Certif...
# 12  Microsoft Power BI Data Analyst Professional C...
# 13        Andrew Ng  AI for Everyone  COURSERA Review
# 14  Math for Machine Learning by Imperial  Courser...
# 15  IBM Full Stack Software Developer Professional...
# 16  Machine Learning Specialization on Coursera  R...
# 17  I Reviewed the Python For Everybody Specializa...
# 18     7 Keys for Prompt Engineering  Coursera Review
#
#                                              raw_text
# 0   what do we think about Corsair we say it's one...
# 1   so I've mentioned Coursera in a handful of my ...
# 2   if you want to study something new but don't h...
# 3   hey guys Lewis here and in today's video I wan...
# 4   what's going on guys it's Moda same here and t...
# 5   I'm sure you've seen the videos making signifi...
# 6   my favorite online learning platforms so let's...
# 7   unlock unlimited learning with Coursera plus h...
# 8   Coursera review hi guys welcome back to anothe...
# 9   Microsoft ux design professional certificate t...
# 10  metadata analyst professional certificate this...
# 11  Microsoft business analyst professional certif...
# 12  Microsoft power bi data analyst professional c...
# 13  here's my review of the course AI for Everyone...
# 14  I recently completed the mathematics for machi...
# 15  IBM stock software developer professional cert...
# 16  what's going on everybody welcome back to anot...
# 17  hey guys it's Greg I don't know how I missed i...
# 18  I just completed the scores on prompt engineer...

# %%
summarized_text = []
drop_index = []

# %%
tokenizer = BartTokenizer.from_pretrained('facebook/bart-large-cnn')
model = BartForConditionalGeneration.from_pretrained('facebook/bart-large-cnn')

for i in range(len(raw_text)):

    text = raw_text['raw_text'][i]

    if (text is np.nan):
        print(f'Text is not available at index {i}')
        drop_index.append(i)
        continue

    inputs = tokenizer(text, max_length=1024, return_tensors='pt', truncation=True)
    summary_ids = model.generate(inputs['input_ids'], max_length=150, min_length=30, do_sample=False)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    summarized_text.append(summary)
    print(f'Text at {i} has been summarized')
# Out:
# Text at 0 has been summarized
# Text at 1 has been summarized
# Text at 2 has been summarized
# Text at 3 has been summarized
# Text at 4 has been summarized
# Text at 5 has been summarized
# Text at 6 has been summarized
# Text at 7 has been summarized
# Text at 8 has been summarized
# Text at 9 has been summarized
# Text at 10 has been summarized
# Text at 11 has been summarized
# Text at 12 has been summarized
# Text at 13 has been summarized
# Text at 14 has been summarized
# Text at 15 has been summarized
# Text at 16 has been summarized
# Text at 17 has been summarized
# Text at 18 has been summarized

# %%
summarized_data = pd.DataFrame({'title': raw_text['title']})
summarized_data = summarized_data.drop(index=drop_index)
summarized_data['summarized text'] = summarized_text

# %%
summarized_data.to_csv('C:/Users/Kayla/Documents/kuliah/Semester 5/Text Mining/Data/SummarizedDataVideo.tsv', index=False, sep='\t')
