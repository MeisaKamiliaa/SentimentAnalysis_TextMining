# %% [markdown]
# # Import Comment Data

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('sentiment_data.tsv', sep='\t')
df
# Out:
#                                                comment
# 0                 I’m interested in doing tech courses
# 1    Not yet, there are many things I need to under...
# 2     @berryberrystrawberry2428  Video explanations...
# 3     @gradehacker  I'm conversational by now. I us...
# 4    Was looking for data analyst related boot camp...
# ..                                                 ...
# 582  Hey people i want to ask you that what if i co...
# 583  should i take the third course if i want to be...
# 584                      Is this course out dated now?
# 585  I just need the best course to help become a m...
# 586  can you please do a review on python 3 program...
#
# [587 rows x 1 columns]

# %% [markdown]
# # Sentiment Analysis Using RoBERTa

# %% [markdown]
# ## Import sentiment analyzer

# %% [markdown]
# The model used is Facebook's RoBERTa large model that was trained on Multi-Genre Natural Language Inference (MNLI).

# %%
from transformers import pipeline

model = pipeline('zero-shot-classification', model='roberta-large-mnli')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\WIN10\anaconda3\lib\site-packages\transformers\activations_tf.py in <module>
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# c:\Users\WIN10\anaconda3\lib\site-packages\transformers\utils\import_utils.py in _get_module(self, module_name)
#    1792         try:
# -> 1793             return importlib.import_module("." + module_name, self.__name__)
#    1794         except Exception as e:
#
# c:\Users\WIN10\anaconda3\lib\importlib\__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# c:\Users\WIN10\anaconda3\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# c:\Users\WIN10\anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# c:\Users\WIN10\anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# c:\Users\WIN10\anaconda3\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# c:\Users\WIN10\anaconda3\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# c:\Users\WIN10\anaconda3\lib\importlib\_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# c:\Users\WIN10\anaconda3\lib\site-packages\transformers\models\roberta\modeling_tf_roberta.py in <module>
#      26
# ---> 27 from ...activations_tf import get_tf_activation
#      28 from ...modeling_tf_outputs import (
#
# c:\Users\WIN10\anaconda3\lib\site-packages\transformers\activations_tf.py in <module>
#      26     if parse(keras.__version__).major > 2:
# ---> 27         raise ValueError(
#      28             "Your currently installed version of Keras is Keras 3, but this is not yet supported in "
#
# ValueError: Your currently installed version of Keras is Keras 3, but this is not yet supported in Transformers. Please install the backwards-compatible tf-keras package with `pip install tf-keras`.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8956\2374965110.py in <module>
#       1 from transformers import pipeline
#       2
# ----> 3 model = pipeline('zero-shot-classification', model='roberta-large-mnli')
#
# c:\Users\WIN10\anaconda3\lib\site-packages\transformers\pipelines\__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     938     if isinstance(model, str) or framework is None:
#     939         model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 940         framework, model = infer_framework_load_model(
#     941             model,
#     942             model_classes=model_classes,
#
# c:\Users\WIN10\anaconda3\lib\site-packages\transformers\pipelines\base.py in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     262                         classes.append(_class)
#     263                 if look_tf:
# --> 264                     _class = getattr(transformers_module, f"TF{architecture}", None)
#     265                     if _class is not None:
#     266                         classes.append(_class)
#
# c:\Users\WIN10\anaconda3\lib\site-packages\transformers\utils\import_utils.py in __getattr__(self, name)
#    1780         elif name in self._class_to_module.keys():
#    1781             module = self._get_module(self._class_to_module[name])
# -> 1782             value = getattr(module, name)
#    1783         elif name in self._modules:
#    1784             value = self._get_module(name)
#
# c:\Users\WIN10\anaconda3\lib\site-packages\transformers\utils\import_utils.py in __getattr__(self, name)
#    1779             value = Placeholder
#    1780         elif name in self._class_to_module.keys():
# -> 1781             module = self._get_module(self._class_to_module[name])
#    1782             value = getattr(module, name)
#    1783         elif name in self._modules:
#
# c:\Users\WIN10\anaconda3\lib\site-packages\transformers\utils\import_utils.py in _get_module(self, module_name)
#    1793             return importlib.import_module("." + module_name, self.__name__)
#    1794         except Exception as e:
# -> 1795             raise RuntimeError(
#    1796                 f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1797                 f" traceback):\n{e}"
#
# RuntimeError: Failed to import transformers.models.roberta.modeling_tf_roberta because of the following error (look up to see its traceback):
# Your currently installed version of Keras is Keras 3, but this is not yet supported in Transformers. Please install the backwards-compatible tf-keras package with `pip install tf-keras`.

# %% [markdown]
# ## Define sentiment labels

# %%
labels = ['positive', 'negative', 'neutral']

# %% [markdown]
# ## Classify all sentiments

# %% [markdown]
# ### Create classifier function

# %%
def classify_comment(comment):
    classified = model(comment, labels)
    print(classified)
    return pd.Series({
        'sentiment': classified['labels'][0],
        'confidence interval': classified['scores'][0]
    })

# %% [markdown]
# ### Classify sentiments

# %%
df[['sentiment', 'confidence interval']] = df['comment'].apply(classify_comment)
# Out:
# {'sequence': 'I’m interested in doing tech courses', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.6811542510986328, 0.24752849340438843, 0.07131725549697876]}
# {'sequence': 'Not yet, there are many things I need to understand about this platform? How can we communicate', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.6512821912765503, 0.2479037046432495, 0.10081414133310318]}
# {'sequence': ' @berryberrystrawberry2428  Video explanations but what I have used is very interractive and at the end of each video you can download worksheet with all the words just learned in the video. I have used yonsei university course to learn korean. The courses vary with different topics though.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.6697995066642761, 0.2584182620048523, 0.07178216427564621]}
# {'sequence': " @gradehacker  I'm conversational by now. I use mix of free resourses including the coursera courses.", 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.5175343751907349, 0.3968522548675537, 0.08561338484287262]}
# {'sequence': 'Was looking for data analyst related boot camps come to find that my local uni charges over 13000, yet Coursera is about 59$', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.8841791152954102, 0.0923110693693161, 0.023509828373789787]}
# {'sequence': "Video lectures are not the same as in-person learning, where your work is reviewed by a learned expert, with feedback given, and with the ability to ask questions for clarification. Peer-grades aren't worth much. So, it's a big price difference but a big difference in what you're getting. (Still, we all know higher ed is overly priced now.)", 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.5821367502212524, 0.2609705328941345, 0.15689273178577423]}
# {'sequence': 'Thank you for this in depth review! I think you were really fair.\\n\\nMy university gives out free Coursera to all of the students who want it, so I don\'t have to pay for certificates, but I think I would probably continue using the platform even after I graduated and didn\'t \'t have free access anymore.\\n\\nI think it is a great way to deepen your knowledge in your own field, or try other, unfamiliar fields as well. All of the courses are high quality and a lot of them are even enjoyable to take and they never feel like a chore.\\n\\nMy only problem is that peer reviews are nothing more than a joke. It is not even that you are not reviewed by experts, but your course mates usually put zero effort into reviewing your work. I never got any constructive criticism, they usually just say "Good.", probably without reading what I wrote, or say "Could have been better".\\n\\nAlso, I wish they had more subjects in Humanities. There are only a couple of literature/culture courses.', 'labels': ['negative', 'positive', 'neutral'], 'scores': [0.732061505317688, 0.1410013735294342, 0.1269371509552002]}
# {'sequence': 'So if you pay the 50 dollars per month you can do any of the courses that cost 50 dollars? its just kind of like a subscription to Netflix that gives you access to all of its shows apart from the advanced courses in this case that cost over $2000 USD??', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.5358901619911194, 0.3080853819847107, 0.15602445602416992]}
# {'sequence': 'If we buy one course is it life time accessible or it will be over within the given period of time', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.6441296339035034, 0.20909495651721954, 0.14677539467811584]}
# {'sequence': 'Hello, I signed up for the Teamwork and Creativity course, it has 5 modules. I have just answered the tasks of the first module and taken the final exam, which is subject to a fee. I wanted to ask if we have to pass all five modules in this mentioned course to get a certificate or can we get a certificate after passing the each module?', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.6120445728302002, 0.21392837166786194, 0.17402705550193787]}
# {'sequence': 'You will get a certificate for each individual course and then one more when you complete all of them, aka complete the specialisation. This means that if you are only interested in completing certain courses, not all of them, you can, but to earn the final certificate you have to complete all of the courses.', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.44060784578323364, 0.4241223931312561, 0.13526973128318787]}
# {'sequence': 'Question: why do I get a certificate for each course I finish? Like they’ll be 4 parts and I get a certificate for all of them? Should it be just one final certificate at the end?', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.4351152181625366, 0.4234854280948639, 0.14139936864376068]}
# {'sequence': 'so if i take a free course & succeed i have the option to pay for the certificate when i’m done?', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.5257167220115662, 0.3856493830680847, 0.08863390982151031]}
# {'sequence': 'Somehow it doesn’t let me have a free course, though it says the course is free. What may be a problem?', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.7518777847290039, 0.1509493738412857, 0.09717288613319397]}
# {'sequence': 'Does it offer Accounting courses?', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.4150916635990143, 0.316800594329834, 0.26810768246650696]}
# {'sequence': 'I took several courses, great contents. My challenge here comes in and I need help with payment. I woud wish to do payment direct from bank is it an available option? Payment criteria CANNOT work for me where I am .', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.4695586562156677, 0.3903118669986725, 0.14012953639030457]}
# {'sequence': "What about people that are not in university? \\nI mean, I finished high school like 20 years ago and that was it.\\nWould someone like me be able to learn the free courses? \\nIt's not like I am that bright... unfortunantly.", 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.7431296706199646, 0.20061789453029633, 0.05625242739915848]}
# {'sequence': 'I have only done two courses and it seems to have some boring structure and a lot of fluff. like they will have a 2 minute overview and then a 1 min conclusion on a topic I just saw.', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.929785966873169, 0.051168132573366165, 0.019045831635594368]}
# {'sequence': "What happens if we don't finish the subscription course in time?", 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.5211076140403748, 0.3390994071960449, 0.1397930085659027]}
# {'sequence': 'Coursera is not an accredited platform per se?  WTF? "Coursera Certificates Are Not Accredited. While a Coursera certificate can look good on your resume, it\'s important to keep in mind that these certificates are not accredited. That means they likely won\'t be accepted as credit towards a degree or other formal education program."', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.7766026854515076, 0.1709093302488327, 0.05248800665140152]}
# {'sequence': 'Are Coursera Certificates certifiable to get a job?', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.4304557144641876, 0.33910828828811646, 0.2304360419511795]}
# {'sequence': 'What is difference between course, specialization and prifessional certificate. I am a pm and want to learn ux, but so many options came. No idea which one to pick frin the beginner filter :(', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.8190929889678955, 0.1469724476337433, 0.03393452614545822]}
# {'sequence': "Is it possible to do the course if I don't have a computer? Can I do everything through phone?", 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.5450364351272583, 0.3183501362800598, 0.13661347329616547]}
# {'sequence': 'I would like to take some easy courses like virtual assistant, how do I go about', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.4603390693664551, 0.4378179609775543, 0.10184302926063538]}
# {'sequence': 'Can anyone tell me what will be best courses for hospital and management', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.43177297711372375, 0.35821154713630676, 0.21001549065113068]}
# {'sequence': "If I've time is it possible to compete any course in a month? Please reply", 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.5080553889274597, 0.25821948051452637, 0.2337251752614975]}
# {'sequence': 'Dose Coursera provide video lectures too??', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.5148172974586487, 0.32653161883354187, 0.15865103900432587]}
# {'sequence': 'How can I call coursera.', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.8394638299942017, 0.09933570772409439, 0.06120050698518753]}
# {'sequence': 'Are the courses guided?', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.375905305147171, 0.3726462721824646, 0.2514484226703644]}
# {'sequence': "Brother I recently opened in coursera account but I can't get free courses how to I get free courses method please????", 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.867379367351532, 0.10144086182117462, 0.031179707497358322]}
# {'sequence': 'I want to learn c language from coursera and iam in my 1st year of engineering in ece i want a degree too', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.44189247488975525, 0.3427072763442993, 0.21540020406246185]}
# {'sequence': 'Is there any scientific evidence of casteism or regionalism against Coursera, EdX, Future Learn, Udemy, Unanth ? Say yes or no\\n\\nNo\\nWhat about pluralsight\\n\\nNo\\nWhat about interaction design foundation or togaf\\nNo.\\n\\nWhat about brainbench ?\\nNo.\\nWhat about guru nanak English high school, kalyan and boiler plant secondary high school trichy\\n\\nThere is no specific scientific evidence to suggest casteism or regionalism against these schools.\\n\\nChatGPT ️️\\n\\n\\n\\n\\nChatGPT ️️', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.5245020985603333, 0.3505079448223114, 0.12499000132083893]}
# {'sequence': 'Do we have to give qyizzes under webcam submission . What are readings in courses', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.5421280264854431, 0.2997577488422394, 0.15811428427696228]}
# {'sequence': ' @jegaevi7371  thanks for sharing is it for the professional course which had peer based assignment too.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.6714918613433838, 0.25744637846946716, 0.07106167823076248]}
# {'sequence': " @gradehacker  They also offer financial aid for those who can't afford to pay for the courses.", 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.5580487847328186, 0.34229448437690735, 0.09965673089027405]}
# {'sequence': "Coursera is one of the biggest piles of trash I've ever seen. Major ripoff. Take a bootcamp course instead.", 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.9722263216972351, 0.017537236213684082, 0.010236473754048347]}
# {'sequence': 'I completed 162 courses and 13 specialities on Coursera and i highly recommend it. The content quality of each course was really excellent', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9638538360595703, 0.030068445950746536, 0.006077741738408804]}
# {'sequence': 'and for how long have you been using Coursera, or took you to earned those?', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.41797322034835815, 0.2947326898574829, 0.28729403018951416]}
# {'sequence': 'Can u recommend some language course like java and python on course era. And web development ?', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.46881505846977234, 0.43499019742012024, 0.09619472175836563]}
# {'sequence': "I'm a college grad and took two courses from Coursera and graduated with two certificates from Coursera. I was able to gain 24 credits from Coursera and transferred the credits to another University!", 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.7374395132064819, 0.19603390991687775, 0.06652655452489853]}
# {'sequence': 'Did the institution you took the courses from give you credits? Or did you have to show it to your university and convince them to give you credits?', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.4297616183757782, 0.39971181750297546, 0.17052656412124634]}
# {'sequence': 'My concern is are they accredited courses for big universities', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.8050631880760193, 0.13131257891654968, 0.06362415105104446]}
# {'sequence': 'I was a drop out student last 5 years ago. Now I found coursera as my way of motivation and success to have a higher rate of getting a job.', 'labels': ['positive', 'negative', 'neutral'], 'scores': [0.5059471726417542, 0.26122748851776123, 0.2328253537416458]}
# {'sequence': ' @kentadran  Hello, if you will, could you please share your experience on coursera as of now? Did you get a job facilitated by those courses? Thank you.', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.634685754776001, 0.24472564458847046, 0.12058858573436737]}
# {'sequence': ' @Seeker7257 my experience is overwhelming positive, it did gave me a new chance of studying as I got no professional degree. Yes I did have a job facilitated by those courses. I am now working on a Chemical Factory', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9801394939422607, 0.017917755991220474, 0.0019427556544542313]}
# {'sequence': ' @kentadran  Thank you for reply, so accordingly, those courses have the potential to allocate an entry level job or the likes? That means, if we complete a particular course, we are left with opportunities, right? \\n\\nI am a collage dropout, and am wondering as to what these courses can do for me. Thank you.', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.5201312899589539, 0.37058931589126587, 0.1092793345451355]}
# {'sequence': " @Seeker7257  Yes, completing the course & having the knowledge of that will surely be something great to add unto your resume/cv/bio-data. There are several courses you can choose from, some requires payment some are not. I took a course which was made by a private university in the states and the instructor is really professional on her videos, even tho you don't have the full set of ideas behind that course it still explains to you like you are kindergarten on a class. They also provide transcripts for you to read if you have time. I even learned Japanese with it. Well my recommendation from choosing a course is something you really love and like. I happened to choose a course on my college days and ended up not liking it. So better look for the one that will totally make you grind for more.", 'labels': ['negative', 'positive', 'neutral'], 'scores': [0.6604611277580261, 0.1760961413383484, 0.1634427309036255]}
# {'sequence': 'I took up business courses in Coursera, most especially in project management. Today, I am now a project manager for two marketing agencies in the US. Coursera helps me to finally use my knowledge I learned in that platform in my role.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.8884232640266418, 0.0845508798956871, 0.02702588029205799]}
# {'sequence': "That's great!! congrats. What is the best Project management course at coursera which will make me understand everything about PM?", 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9303693175315857, 0.058816321194171906, 0.0108143026009202]}
# {'sequence': ' @RichardWalls  As a digital marketer, I just realized I needed to know more about project management since they go well together. So, I decided to learn more about it. I started leading projects but I didn’t have the title. I applied last year and my different clients were impressed by my experience and credentials and decided to give me the project manager role in their companies.\\n\\nCoursera helped me advance my career. ️', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.6302717328071594, 0.30089738965034485, 0.06883084774017334]}
# {'sequence': ' @zaidalmashan517  I love UC-Irvine’s project management courses. They’re straightforward and they helped me to be equipped in my role.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9467565417289734, 0.04551931098103523, 0.007724099792540073]}
# {'sequence': 'Do you have a degree besides a Coursera certificate?', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.4255220890045166, 0.31223219633102417, 0.26224571466445923]}
# {'sequence': 'This is the first of very few comments that have confirmed a career gain from coursera.  Most of them are either flexing on completing a bunch of courses or raving about how great they are without saying anything about actually getting a job from it.  Hopefully your not just a bot.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.6815145015716553, 0.17347973585128784, 0.14500579237937927]}
# {'sequence': "I just started on coursera last week and I can't believe that I didn't do so earlier. I think the contents are put together much better and nore professional than Udemy.  I give it a 5 .", 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.874599039554596, 0.09173254668712616, 0.03366848826408386]}
# {'sequence': 'Yup am wanting to do a bunch of courses on coursera. The good thing...is it’s free unless you are wanting their certificates.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9501546621322632, 0.04397187754511833, 0.005873422138392925]}
# {'sequence': 'Do you still recommend Coursera?', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.3839516043663025, 0.3598661422729492, 0.2561821937561035]}
# {'sequence': 'Same, I completed a course from Bocconi and it was the first online course ever, that I enjoyed from the beginning. It motivates you and they do a great job on explaining topics to someone with few or no prior knowledge.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9487158060073853, 0.046368978917598724, 0.004915226250886917]}
# {'sequence': "I have 0 self confidence and have never taken anything beyond high school.  I know I know, that's crazy!  After seeing what this online course is all about and currently in a mid-life crisis, I want to try at least one course.  I'd like to have a certificate in something...I was actually looking at the Cyber Security course and may take the plunge....Thanks for the helpful information.", 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.6915007829666138, 0.22063863277435303, 0.0878605768084526]}
# {'sequence': 'All the best! Hope you plunge into that course and complete it.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.8917657136917114, 0.09764343500137329, 0.010590801946818829]}
# {'sequence': 'Thanks for this reflection, coursera certificates really add value in career advancement, another important element that distinguish coursera with other learning platforms is financial aid option.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9640681147575378, 0.02895447239279747, 0.006977491080760956]}
# {'sequence': 'How do you get the certificate in Coursera?', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.3633744716644287, 0.318827360868454, 0.3177981376647949]}
# {'sequence': 'Some certifications give you credit hours, now there are degrees and masters on the website. I’m in IT support, looking into cyber security analyst, and AZU’s computer science masters with a specialization in cybersecurity\\n\\nPS. I’m coming from a non tech background. I only know CSS, HTML and SPSS. I majored in Sociology at UVA. It’s very doable guys! Don’t give up, I love Coursera!', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.5827354192733765, 0.2496325522661209, 0.1676320731639862]}
# {'sequence': 'Yes I love it too, I highly recommended to my friends using Coursera and pay for it', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9463746547698975, 0.049106959253549576, 0.004518419969826937]}
# {'sequence': "I'm currently a new pre-nursing student and plan on taking Coursera's anatomy and physiology course prior to actually enrolling in that course with my school so that I can frontload the knowledge I need so that when I actually take the course I can be as successful as possible. I'm super excited I came across Coursera.", 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.7707403302192688, 0.17451491951942444, 0.05474475026130676]}
# {'sequence': "I've been studying from MOOCs for years and always have come across Coursera (paying money for certain courses has turned me away), but now I am reconsidering and will be working on the equivalent of a doctorate and actually having something to show for it. I've wasted money over the years on superfluous things but have come to realize investing in education (outside of buying textbooks) is is well worth it.", 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.6433059573173523, 0.17920364439487457, 0.17749042809009552]}
# {'sequence': 'Hi Richard. I was looking for the perfect review on Coursera and I am in the right place. Thank you for this video. I am starting classes on Coursera.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9063666462898254, 0.08262032270431519, 0.011013013310730457]}
# {'sequence': 'hi my friend! aftr 9 month have coursera has been helpfull for your interests?', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.5287256240844727, 0.33021602034568787, 0.14105834066867828]}
# {'sequence': 'Coursera is brilliant. All courses I have completed have supported me in my career.️', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9399067163467407, 0.05509346351027489, 0.004999867640435696]}
# {'sequence': 'Taking Coursera courses has been the best thing that happened to me in the last 2 years.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9671202898025513, 0.029113469645380974, 0.0037661821115761995]}
# {'sequence': 'I appreciate your review. I completed my first Coursera course just recently. Mine was available through the university where I work so it was free. I agree the peer-grading feedback was hit or miss. I did learn a lot from reading what other people turned in for assignments. And I personally tried to provide decent feedback. Some of the feedback was really thoughtful. Some was not even written in complete sentences! LOL! But I enjoyed the course a lot and will probably continue in the certification it is part of.', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.539607048034668, 0.2465319037437439, 0.21386103332042694]}
# {'sequence': 'Coursera will give you skills but your BODY OF WORK is what will get you hired. You need a portfolio of work nowadays to stand out. Merely knowing and having the certificate is not enough. Start a Youtube Channel and/or website to showcase. your skills. This is a MUST.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.46453723311424255, 0.3651759922504425, 0.17028678953647614]}
# {'sequence': "I've just finished the AWS IOT course.. it was not for beginner and fortunately i am familliar with AWS from last year. Some exercise was written in 2019 and as 2021 AWS has upgrading some services,  so after exercise 3 it is not meet the required upgraded version. But after all,  it is boosting my confidence for this pandemic era as coursera approved my financial aid.", 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.5510319471359253, 0.3772834539413452, 0.07168462127447128]}
# {'sequence': 'I commend you on clarifying a little of the difference between the specialization and the courses.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9681735634803772, 0.02926335111260414, 0.00256308913230896]}
# {'sequence': "Thank you for making this video. I'm stuck between taking a payroll course(s) with Coursera or taking a course with CUNY. I live in NYC and the price point is a huge difference. I'm currently paying for my son's college tuition and was wondering if Coursera would be worth the money as I would like to further my knowledge in finance but don't want to waste money. I truly appreciate your honesty and thoroughness.", 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.5457566976547241, 0.33456695079803467, 0.11967633664608002]}
# {'sequence': "I've taken Cybersecurity in college and Coursera and Coursera was excellent! They explained everything in a way I could better understand. The free course is nothing but listening so making sure you takes notes is highly important to make sure you know you are learning & understanding the content. Highly recommend ", 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9483435750007629, 0.0414465107023716, 0.010209903120994568]}
# {'sequence': "Coursera is great, but most of the courses I have done there were built in such way that if you do not achieve 100% score, you probably can not read. Exception being e.g. Pavel Pevzner's Bioinformatics specialisation or the original 2012 version of the Probabilistic Graphical Models course (has been diluted and split into several courses now, so not sure about that one any more).\\n\\nIn this respect, I found MITx courses on edX  better (and I like edX UX significantly more as well - yes, this is subjective). In order to pass those, you have to understand the subject matter, apply it in a creative way to a problem you have never seen before - so you have to actually think as opposed to Coursera's norm of simple recall quizzes. The only problem of those MITx courses is that they run on extremely crazy schedules, so having full-time job and/or family makes it almost impossible to do them simply because of lack of time.", 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.4042920172214508, 0.3165499269962311, 0.2791581153869629]}
# {'sequence': 'I’m debating on taking courses has anyone taken any and have been able to advance in their careers?  Has your employers or others recognized the education from Coursera', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.5899326801300049, 0.3330540657043457, 0.0770132839679718]}
# {'sequence': 'Udemy is better for learning Python and SQL.  Learn and retained next to nothing after 4 months of python and SQL on Coursera.  Udemy has better hands on so far.  Actually it is almost all hands on.  \\n\\nCurrently taking 100 days to code and SQL boot camps.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.7762734293937683, 0.1408146619796753, 0.08291193842887878]}
# {'sequence': "I'm stopping at 5 - 6 specializations and 2-3 individual courses. The last 3 specializations will based on change management, transformation, and SQL. Should be done by the end of May.... has taken 3 months, but will hopefully be worth it.", 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.5248839855194092, 0.2672497034072876, 0.207866370677948]}
# {'sequence': 'Hi there!\\nSo I study using Coursera. I have taken a few courses on variety of fields I am interested in. I did an introductory marketing course ( from Wharton) and currently doing an accounting course ( also from Wharton). I wanna learn more about different branches of business as I am still trying to figure out what I like the most and what I should choose to pursue my degree. Now I wanna learn about business administration .Can you recommend me some great courses about business management or business administration for newbies on Coursera?\\nThank you ', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.49496299028396606, 0.3827148973941803, 0.12232208251953125]}
# {'sequence': '@RichardWalls My company gives us access to the Coursera+ classes, some of which are taken straight from the UIUC iMBA courses. From what I could see, if you take these courses ahead of enrolling in the iMBA, you can use them towards your degree. Having been a part of both Coursera and iMBA at UIUC, do you know if this is an additional way to save some $$ on the 12 or so credits I currently have access to? Or is it something that you inevitably have to pay for when transferring those credits for consideration/grades? Thanks man, great channel! UIUC and Boston University applications going in this week, in large part thanks to your content!', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9118572473526001, 0.06909328699111938, 0.01904950849711895]}
# {'sequence': 'Do they have due dates on the NBA courses for assignments? I’m at a community college and the professors set due dates for assignments. And sometimes we get 1 to 2 chapters per week. Well, really an average of one chapter. Plus of midterm if that happens depending on the professor and sometimes on rarer cases a final exam. What is Coursera like?', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.44897544384002686, 0.3383444547653198, 0.2126801460981369]}
# {'sequence': 'Awesome video!\\nI am actually thinking about doing a course about Legal Tech and Startups!\\nThanks!\\nCheers ', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9119433164596558, 0.08212022483348846, 0.00593646802008152]}
# {'sequence': 'As a person with no degree but interested in cyber security, would completing cyber security related certificates/courses allow me to step into the job field on a mid-high skill level?', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.6743661165237427, 0.18123437464237213, 0.1443995088338852]}
# {'sequence': 'What do you think about Forage’s courses for college students trying to figure out a career path and how does it compare to Coursera?', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.44950878620147705, 0.3610975444316864, 0.18939368426799774]}
# {'sequence': "I would really like to know if you think it'll be possible to get into the job field of management using Coursera content, knowing that I have no degree. Thank youuu", 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.7282734513282776, 0.16483475267887115, 0.10689180344343185]}
# {'sequence': 'Great content. What do you think about Vonza platform?', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9443928599357605, 0.04967005178332329, 0.0059370845556259155]}
# {'sequence': 'Can one put these on a resume and get a job for example Comptia + and Security + certs and get a job are they accepted by most employers or are these "decorative wallpaper" like a continuation learning which is nice and all lets employers know you seek improvement.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.524734616279602, 0.3871261179447174, 0.08813924342393875]}
# {'sequence': 'I’m in college for bachelors in cyber security, but I want to do IT or project management while still in college  in coursera would that make sense? Or be worth it ?', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.6642598509788513, 0.19966304302215576, 0.13607709109783173]}
# {'sequence': 'Hi Richard, \\nOne question: If I complete for example a financial accounting certificate from Penn University, do I get the certificate from Penn University or from Coursera?\\nThanks', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.4953460097312927, 0.2843533754348755, 0.2203005999326706]}
# {'sequence': ' @RichardWalls  Thanks, but will the certificate show I completed the course from Penn University?', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.42304328083992004, 0.3810577392578125, 0.19589897990226746]}
# {'sequence': ' @richardcontell1314  yup, but it does not counts as a Credit, unless the course says so. I did a course from yale about psych and it has the yale logo and the coursera as well. It says you completed a xourse from that uni from coursera, your name and the teachers signature', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.513424277305603, 0.3211364448070526, 0.16543924808502197]}
# {'sequence': "I just did Microsoft Azure Fundamentals and it was riddled with problems. \\nBroken links to Azure sandbox environments, steps that mention non-existent settings, or are in a different place now, inconsistent video player functionality from lesson to lesson - some fullscreen, some don't, some you can change speed, some you can't. And mid video tests that cut the presenter off mid-sentence and pop up before the fact have been taught. The whole experience was infuriating. Are their other courses falling out of sync like this, or was this just really bad luck?", 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.9460310339927673, 0.043846745043992996, 0.010122217237949371]}
# {'sequence': 'Greetings and Salutations \\n\\nFrom the free course offered in \\nNew California Republic ', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.6030382513999939, 0.3712483048439026, 0.025713428854942322]}
# {'sequence': 'Tried one course - Python programming basics. It was a lot of "water" in what seemed to be like an intro to an actual course, but then there was a "test", which one had to pass to get further. I was extremely frustrated to put it mildly, seems like the aim of such "test" is not to test ones knowledge, but with how much BS one is willing to put up with.\\nUser interface isn\'t brilliant either - here on YouTube you can use fast backward and forward, if you missed something, on Coursera it just isn\'t there. I don\'t remember anymore, what other issues with UI there was, but I recall myself thinking how ironic it is to have those for a site, which claims to teach web design and programming skills.', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.8941876888275146, 0.08557668328285217, 0.020235616713762283]}
# {'sequence': 'I tried to access coursera, but they give me only 7 day free trial. Can anyone say to me how I got the courses for free, please', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.7334629893302917, 0.1989622414112091, 0.06757474690675735]}
# {'sequence': 'Course content excellent but very limited support resources ie no in person chats spend so much time trying to find out how to find a template needed to complete peer reviewed exercises ect.. overall the course organization can be poor but the content I have found to be exceptional.', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.45756176114082336, 0.35686373710632324, 0.18557456135749817]}
# {'sequence': 'I was working 9$ front desk gym , Coursera courses saved me now I’m building a data center', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.8815913796424866, 0.08220895379781723, 0.0361996628344059]}
# {'sequence': "Sir, I've a question\\nIs this course for the people who are small and they don't graduated of school?", 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.45073428750038147, 0.4220029413700104, 0.12726275622844696]}
# {'sequence': 'Hi Richard, I was planning on doing a course related to AI specialized in Business on coursera. Is there anything you can help me out with regarding this course?\\nLike any kind of suggestions that could help me out with this course later in the coming future', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.47489362955093384, 0.2974831461906433, 0.22762328386306763]}
# {'sequence': 'I have some questions if i take EMT course in University of Colorado can i use that as my job everywhere like in Canada, USA, and UK?', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.6855836510658264, 0.1651090383529663, 0.14930731058120728]}
# {'sequence': 'Debating whether or not I want start using coursera.', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.5592988133430481, 0.33284756541252136, 0.10785365104675293]}
# {'sequence': 'Will I get a paid certificate if I completed only one course out of a whole specialization?', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.44775834679603577, 0.3748212158679962, 0.1774204969406128]}
# {'sequence': "I badly wanted to take a course but i don't have a laptop. I wish it could be available on just a phone.", 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.8501810431480408, 0.11828125268220901, 0.03153770789504051]}
# {'sequence': 'Do you know any details how to get in touch with workers there? Cuz I’ve completed the course, but can’t get a certificate… \\nThanks for your reply in advance)', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.752480685710907, 0.15421363711357117, 0.09330566227436066]}
# {'sequence': 'What do you recommend, guys, taking psychology courses at Coursera or IAP Career College? I’m not sure. Can anyone help me? Because I have searched of Coursera, and it has a D- grade from the Better Business Bureau. IAP has a high grade from Better Business Bureau.', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.8119094967842102, 0.15007145702838898, 0.0380190871655941]}
# {'sequence': "thank you for explaining... \\ni just wanna know how can i get free certificate from coursera when I'm done with certain courses. I'm from Sudan and where I'm from visa card and master card still not working lol.", 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.6659077405929565, 0.2117488533258438, 0.12234335392713547]}
# {'sequence': "Hi, Rich! If ever I want to enroll myself to this program, it'll take 4 years, right? And will there be payment in case I want it to be credited as a degree diploma? Does coursera credit my finished 1st year, like that?\\n\\nA response from you will be sooo helpful!", 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.3697859048843384, 0.35650762915611267, 0.27370646595954895]}
# {'sequence': 'I’m currently a new sport science student,and I started taking courses about sport science and science of exercise,do you think this degree would help me when I want to apply to another university around the world?', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.5386524200439453, 0.24394609034061432, 0.21740151941776276]}
# {'sequence': 'i cant see the date they make the course how i can see it?', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.7699934244155884, 0.1649935394525528, 0.06501302868127823]}
# {'sequence': 'I’ve learned UI/ UX alone without courses in 1 month ! Only Google .', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.5428552031517029, 0.23759089410305023, 0.21955391764640808]}
# {'sequence': 'Can anyone confirm the cost? I am seeing $39 monthly. Do courses vary in cost in addition to the monthly $39 subscription fee?', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.5041661262512207, 0.30362802743911743, 0.19220583140850067]}
# {'sequence': 'Richard Walls - Career Dev & Finance It’s such unbelievable price comparing those profit making courses provided by some professional bodies.', 'labels': ['negative', 'positive', 'neutral'], 'scores': [0.4640561044216156, 0.3388198912143707, 0.19712397456169128]}
# {'sequence': 'Sir can you tell me from these courses how i will get a job mean i have done many courses but i dont know ho to use these courses for sell or earn a money from this. Can you help me how can i get a job from these courses Thanks.', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.48361802101135254, 0.3536635637283325, 0.16271841526031494]}
# {'sequence': 'I have a dumb question I am doing BDS currently in 3rd year But I have interest in Psychology..If I do online courses from coursera or any other sources can I become psychologist lol I mean Counsell people online bcz obv can’t be a clinical psychologist..', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.544458270072937, 0.3756571114063263, 0.07988462597131729]}
# {'sequence': 'Do these courses have a good return on investment for a complete noob.', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.49412107467651367, 0.4159702956676483, 0.08990858495235443]}
# {'sequence': "I'm thinking about taking online animation course which platform do you recommend?", 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.44116249680519104, 0.3698296546936035, 0.18900783360004425]}
# {'sequence': 'Is there tests at the end of the paid courses?', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.4704304337501526, 0.33782029151916504, 0.19174931943416595]}
# {'sequence': 'Hi I am planning to take some coding related courses...Is it worth to take it via course era or via universities', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.6519972681999207, 0.22135533392429352, 0.12664733827114105]}
# {'sequence': "Hi, just a quick question. \\nFor ANY free course they offer, you can get a paid certificate in the end? \\nSo all of the process is free, but if you want a certificate to prove you've completed the course, you have the option to get a paid certificate?", 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.6098974347114563, 0.2303382158279419, 0.159764364361763]}
# {'sequence': 'Do you get a job with Coursera certificate or not?', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.4308948218822479, 0.39702701568603516, 0.17207814753055573]}
# {'sequence': "Thank you for Video!\\nI need an advice, please...\\nI study online in university but I while I am studying I need more experience and skills which I do not get from university. I am thinking to try to  get a course from coursera, but I am not sure if I can work with certificate from coursera? Because I didn't graduate yet, but I want to start working, can I work with that certificate? Is it possible or not ?\\n If you know any good courses for event management and Marketing, I would appreciate it !! thank you ", 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.3459798991680145, 0.3457925021648407, 0.30822762846946716]}
# {'sequence': 'I\'m interested but I don\'t see how people whom have been high school drop outs can now attend Berkley. My question is say I use coursera and I get my B.A in computer science and I apply to IBM London, and the recruiter sees I\'ve got a b.a from Harvard University. He decides to check with the dean of Harvard to make sure I\'ve graduated from there. Is that dean or registrar office going to say "hey, yeah he graduated from here I can see him in our program". Or will they not have any information of me ever using there services.', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.6893895268440247, 0.23847787082195282, 0.07213260978460312]}
# {'sequence': '1. does it has weight in the course, 2-- will they help us get job, 3 how will be course conduct via zoom link, 4-- what type of job will i get, 5 after completing do we get job anywhere --   Salary how much i get ?\\nthank u', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.5151311755180359, 0.3497886061668396, 0.13508030772209167]}
# {'sequence': 'Cuestión si I can take more then one course for same price ?', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.5125463008880615, 0.29229891300201416, 0.1951548457145691]}
# {'sequence': "i can't believe the amount of courses you guys are saying you take. is this average? is this necessary to remain competitive for your fields? i often try to learn things on my own, but i haven't been able to use one of these services. i would like to bring myself to the level that i have real certifications or other things i can use to get a job. but sometimes i wonder if it's worth it or that what really  counts is real experience. is it possible to move into a new career with one of these certificates? is this similar to actual college courses? the price is not extremely cheap and i wouldn't expect it to be if this is legit, but i don't even have a computer set up at the moment and i question whether or not it will be worth it in the long run.", 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.7060724496841431, 0.2545780539512634, 0.039349496364593506]}
# {'sequence': 'It is not just about certifications but also knowledge delivered in a structured and bit sized manner which sticks with you if you do the courses correctly and with patience. Certifications are the proof that yes you have the drive to upskill yourself in the field of your interest. It shows your own drive to improve yourself to be a better version of you.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.6748200058937073, 0.257583886384964, 0.06759607046842575]}
# {'sequence': 'Which IoT courses did you take?', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.3588171899318695, 0.35506653785705566, 0.2861163020133972]}
# {'sequence': " @RichardWalls  Thank you so much, for getting back to me Richard Walls. This is definitely a great starting point for me. I will take this course, and I see that I can enroll today. I appreciate the career development and finance mentoring you offer, it's awesome! I was particularly interested in your journey to becoming a product manager especially in the IoT space (I am working for a tech company that develops software for IoT spaces) . I aspire to be a product manager soon, and I'm working towards it. Thanks for the guidance. I have my eye on a couple of online MBAs to consider, thanks to your video on that... Brilliant!! I am grateful.\\nAny thoughts regarding working towards a Product management certification? Is this worth pursuing, and could you please recommend a great certification that is recognized internationally?  Many thanks!", 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9268159866333008, 0.06277254223823547, 0.010411498136818409]}
# {'sequence': 'Do you recommend it for web development courses ?', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.546852171421051, 0.3549094498157501, 0.09823843091726303]}
# {'sequence': 'I might have guessed YouTube would put a coursera thumbs up to feed its data scrounging operations.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.7333932518959045, 0.18039128184318542, 0.08621539920568466]}
# {'sequence': 'have gotten a job from coursera from the certificats please?', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.42824918031692505, 0.380466490983963, 0.19128429889678955]}
# {'sequence': "can i do the courses even though i'm 16", 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.5202543139457703, 0.3338051736354828, 0.14594055712223053]}
# {'sequence': 'Hi sir, for Coursera can I pay through PayPal balance rather than using credit card? Thanks in advance.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.6337792277336121, 0.2520754933357239, 0.11414526402950287]}
# {'sequence': 'will coursera certificates help me get into a good college?', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.48854994773864746, 0.2752052843570709, 0.23624470829963684]}
# {'sequence': 'Hi. Is that cybersecurity set of courses available with the Coursera plus?', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.6025243401527405, 0.2450971007347107, 0.15237855911254883]}
# {'sequence': 'sir courses are reakky helpful for freelensing work to make money please guide me i am a 1st year student in engeniering college \\nand i want to make some money by freeliencing in graphic desining', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.8306381702423096, 0.13635675609111786, 0.03300505131483078]}
# {'sequence': 'How can i get into the coursera program', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.3482650816440582, 0.33452683687210083, 0.31720805168151855]}
# {'sequence': 'How can I take a course  on Coursera', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.535236120223999, 0.2618570327758789, 0.2029067724943161]}
# {'sequence': 'Love to do courses on Coursera. #CareerXskills', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9229875206947327, 0.06714988499879837, 0.009862571023404598]}
# ...
# {'sequence': 'Does this course come with live classes to learn?', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.46781134605407715, 0.29517340660095215, 0.2370152622461319]}
# {'sequence': 'Can anyone tell me how much the entire course costs for the whole certificate?', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.5763611197471619, 0.289926677942276, 0.13371218740940094]}
# {'sequence': 'If i complete cloud computing course after html css and js will in get a professional certification (iam applying course wise in financial aid).', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.6030546426773071, 0.25456053018569946, 0.14238481223583221]}
# {'sequence': 'Hey Alex, I just landed a Data Analyst internship for the summer and I am really looking forward to it. Your channel has definitely helped me out. \\n\\nI am looking forward to taking this machine learning specialization as well. I’m planning out when to commit the time to study. Work will take up so much of my time in the day!', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.934045672416687, 0.05874702334403992, 0.007207327522337437]}
# {'sequence': "I just finished week one of this course. There is definitely some math! If you're like me and its been a minute since you've really had to work through an equation, I would advise just slowing down and making sure you understand what you're looking at before moving on because each step builds on the last. \\n\\nAndrew Ng is a very good teacher, which is what makes the class work. ChatGPT is also good as an echo chamber. Try to explain the math to it, it will correct you if you get something wrong.", 'labels': ['positive', 'negative', 'neutral'], 'scores': [0.44629666209220886, 0.28496915102005005, 0.2687341570854187]}
# {'sequence': 'Thanks for sharing this! I was looking for a good ML course and this is exactly the suggestion I needed!', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9627493023872375, 0.03091769851744175, 0.006332944147288799]}
# {'sequence': 'So happy my college actually teaches machine learning in the DA program. So interesting.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9556552767753601, 0.04023100063204765, 0.0041137570515275]}
# {'sequence': 'Thanks for sharing this you are a great teacher \\nMy teacher can i get work after finish this courses ??', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.858216404914856, 0.10917987674474716, 0.03260371834039688]}
# {'sequence': 'Hey Alex, up to what level of python do you feel is required to take this specialization. Would you suggest to learn some prior math concepts before heading into this course?', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.4119715988636017, 0.4076021611690521, 0.18042629957199097]}
# {'sequence': 'Hi Shreyas ! I am already taking this course . For python you need to know what functions are , for loops , and what are methods . \\nIn terms of math all you need is college level math . And You dont need to go through anything advance as Andrew goes through them in lessons as well. \\nOne thing i must mention is that if you dont know python then understanding code will be difficult.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.5026537179946899, 0.33269909024238586, 0.1646471619606018]}
# {'sequence': 'Python or any programming knowledge or what I call computational thinking. Then for machine learning, you need statistics(300 level), Linear algebra( An absolute must) if you haven’t taken a course in linear algebra you will never understand machine learning period, and then some multivariate calculus and even basic calc. When I took the MITx class in ml it was clear people just didn’t understand what was going on.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.4742189645767212, 0.37640854716300964, 0.14937244355678558]}
# {'sequence': "Sad that I have to pay for the specialisation because it is not included in my uni's partnership programme with Coursera, but I think the fee will be worth it :) Thanks for reminding us of Andrew Ng using Python for ML, Alex", 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.5654298067092896, 0.2877465486526489, 0.14682364463806152]}
# {'sequence': 'There are 3 courses within this specialisation. You can audit them for free. You will get the whole course just not graded assignments.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.5170219540596008, 0.35322675108909607, 0.12975133955478668]}
# {'sequence': 'They give you 7 days free trial and it costs $49/month after that. If you can go faster, the total cost will be cheaper. I learned most of these stuff back in school, so I was able to go through these courses fairly quick. I am almost done with the 2nd week of the last course in exactly 2 weeks after starting with this specialization. Coursera planned this specialization for 10 weeks total (3+4+3). But if you do it 5x a week at 1.5 hours ea you should be able to finish it in less than 2 months.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.8068627119064331, 0.11980807781219482, 0.07332922518253326]}
# {'sequence': "Hi Alex and everyone, \\nPls I need help on how to upload my certificate from Coursera to Upwork. I've tried but Coursera is not among the list of options in the certification. Thank you all", 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.6867632865905762, 0.24269670248031616, 0.0705399289727211]}
# {'sequence': "great efforts in this channel.\\nI have only simple enquiry as a new sql learner.\\nI haven't made my mind yet whether to use sql server or not. \\nIs sql server the best solution available for those who want to manage and automate databases inside a medium size company.\\nIs there any alternative i need to consider right from the beginning or any applications that is relevant to integrate with the database being used.\\nI consider myself a machine learning enthusiast and and would mostly like to automate business solutions with the engine being used.\\nThanks for taking time to read this.. God bless you.", 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.6659301519393921, 0.24840353429317474, 0.08566626906394958]}
# {'sequence': 'What are the differences to Deep Learning Specialization by Andrew Ng?', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.4351584017276764, 0.3553885817527771, 0.20945295691490173]}
# {'sequence': 'Are all the video recordings in the updated course also new?', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.45314905047416687, 0.35147011280059814, 0.19538085162639618]}
# {'sequence': 'Hey Alex! I have completed this course 3 months back. Is it worth to take it up again? Although I know R and don’t know Python!', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.4512379765510559, 0.4436717629432678, 0.10509026795625687]}
# {'sequence': 'Thanks for the review\\nIs the course also useful for ppl who are more into data analytics ?', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.5771862864494324, 0.35829871892929077, 0.06451492756605148]}
# {'sequence': 'Hey Alex,\\nThanks for the review! Does this course come with a note? (e.g., a pdf or Jyputer notebook).', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.4701181948184967, 0.28138357400894165, 0.24849821627140045]}
# {'sequence': 'Hi Alex,\\n\\nIs this one Specialization course enough to learn Machine Learning and dive into a career related to ML?', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.7585597038269043, 0.13871760666370392, 0.10272271931171417]}
# {'sequence': 'How much money it cost to learn machine learning course from Coursera?', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.4221220910549164, 0.3147059679031372, 0.2631719410419464]}
# {'sequence': 'I have a doubt  , since it is called us Deep learning.ai ..is it just all about deep learning ..or it starts from scratch of ML to Deep learning..of should i do someother machine learning course before taking this... please help me', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.5083171129226685, 0.3820025324821472, 0.10968032479286194]}
# {'sequence': "You have convinced me to take the course . I paid the $48 let's see how it goes", 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.6762874126434326, 0.28215160965919495, 0.04156096652150154]}
# {'sequence': 'Not a fan that this is sponsored by coursera. How can anyone be objective in that case', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.9520605206489563, 0.028994718566536903, 0.01894473284482956]}
# {'sequence': "I took it and was impressed by it (this is Thomas Comerford btw, you responded to a comment of mine earlier today) in that it taught me a lot as a newbie. However, one thing that I noticed is that comparing it to the 4th course in the IBM cert, it doesn't utilize the requests library like the IBM one does. Personally, I think you're better off just skipping it if you're going to take the IBM courses, since the 4th course alone goes over everything and more that the specialization has. The only downside is that the IBM one is very fast paced, and it may feel like you aren't getting a total explanation of the content, so you'll just need to repeat stuff. One thing that you won't get in course 4 of the IBM cert is SQL with Python, but that's because it's another course.", 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.5690168142318726, 0.30947145819664, 0.12151167541742325]}
# {'sequence': 'I have been thinking of opting for this one lately but I am constantly having second thoughts. Can anyone suggest a better course that would be of more value to a potential employer,', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.8322436213493347, 0.0943707600235939, 0.07338565587997437]}
# {'sequence': 'Hi Greg. I am completely new to the development world with background in sociology. No background in coding whatsoever. I have been wanting to start learning development for the past 2 years, but it is overwhelming not knowing where to start from. Can you please advise?', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.556080162525177, 0.37250784039497375, 0.07141197472810745]}
# {'sequence': 'which is the best course for python if i have time.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.8860229849815369, 0.08786884695291519, 0.026108168065547943]}
# {'sequence': 'I have been learning python for 1 month, is it fine to take this course?', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.4116365313529968, 0.40552330017089844, 0.18284016847610474]}
# {'sequence': "hi greg, i've just started the IBM data science professional certificate and I'm really excited about it, should I follow it with Andrew Ng's machine learning or deep learning specialization? I really like both but i can't tell which one is better", 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.5744385123252869, 0.3479178547859192, 0.07764366269111633]}
# {'sequence': 'The problem is that most python courses are just like this. Once you get the basics, it becomes very difficult to grow as a programmer through online courses. The best thing past learning the basics is doing a project, reading the documentations and getting good at copying code from stockoverflow.', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.9671732783317566, 0.023260340094566345, 0.009566446766257286]}
# {'sequence': " @GregHogg  I'm a noob - I think i'll just learn this course on freecodecamp and use actual accomplishments afterwards as credit instead of taking the coursera cert", 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.42456549406051636, 0.3719187378883362, 0.20351578295230865]}
# {'sequence': ' @GregHogg  ok we have a bad course give us where to find a good one', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.9523345232009888, 0.03377257660031319, 0.013893017545342445]}
# {'sequence': "I wanted to take this to get CERTIFIED  at python. But i's already familiar with it so what course should I do? To get certified", 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.5013874769210815, 0.33340945839881897, 0.1652030646800995]}
# {'sequence': 'im not familiar with python so i will take this course \\nbut u said its not enough to master the python so what you suggest me to do or a course to take after finishing this one?', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.5583458542823792, 0.37765491008758545, 0.06399929523468018]}
# {'sequence': 'Hi \\nCan you please review the Data Science Road Map that had been created by Coursera.', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.5022545456886292, 0.30723968148231506, 0.1905057430267334]}
# {'sequence': "I've been interested intrigued with UofM material but I m already in deep in other courses. I'm at the portfolio stage.", 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.4018649458885193, 0.37608176469802856, 0.22205322980880737]}
# {'sequence': 'can anyone tell me where should i start learning python im completely lost i need free resources and proper guidance please help', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.6970670223236084, 0.22876118123531342, 0.07417174428701401]}
# {'sequence': 'Should i do this course or python bootcamp zero to mastery udemy? Which one do you recommend? I am beginner at programming', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.5451492071151733, 0.2798689603805542, 0.17498184740543365]}
# {'sequence': 'Hey man where I can learn python intermediate course for free  I will be waiting for your reply', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.6342514157295227, 0.24176445603370667, 0.12398414313793182]}
# {'sequence': 'Could you do a review of IBM devops and software engineering from coursera please and is it a good start to become a software engineer?', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.45333409309387207, 0.3368346095085144, 0.20983129739761353]}
# {'sequence': 'Hi Greg, what can you advise someone who wants to make a career change from business entering the IT industry? I have been told about Python but read your comment that its become so common. Which courses are worth doing knowing I will be able to get a job offer? Thanks in advance', 'labels': ['neutral', 'negative', 'positive'], 'scores': [0.42594578862190247, 0.33487969636917114, 0.239174485206604]}
# {'sequence': 'Hey Greg, thanks for the review, what would you recommend to a newbie like myself to do AFTER this course that probably is in Coursera?', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.49895501136779785, 0.27136898040771484, 0.2296760380268097]}
# {'sequence': 'Hey people i want to ask you that what if i completed all the 5 courses in this specialization?? will i  get a certificated issued by university of michigan??', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.581400990486145, 0.23512353003025055, 0.1834755688905716]}
# {'sequence': 'should i take the third course if i want to become a data analyst', 'labels': ['neutral', 'positive', 'negative'], 'scores': [0.37769222259521484, 0.3129127025604248, 0.30939504504203796]}
# {'sequence': 'Is this course out dated now?', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.6748040914535522, 0.22454534471035004, 0.1006506085395813]}
# {'sequence': 'I just need the best course to help become a master at python ️', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.5662420392036438, 0.2956371307373047, 0.13812075555324554]}
# {'sequence': 'can you please do a review on python 3 programming specilization. Im having trouble differentiating between that and this course.', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.6557496190071106, 0.25018689036369324, 0.09406351298093796]}

# %% [markdown]
# ## See the final result

# %%
df
# Out:
#                                                comment sentiment  \
# 0                 I’m interested in doing tech courses  positive
# 1    Not yet, there are many things I need to under...  negative
# 2     @berryberrystrawberry2428  Video explanations...  positive
# 3     @gradehacker  I'm conversational by now. I us...  positive
# 4    Was looking for data analyst related boot camp...  negative
# ..                                                 ...       ...
# 582  Hey people i want to ask you that what if i co...   neutral
# 583  should i take the third course if i want to be...   neutral
# 584                      Is this course out dated now?  negative
# 585  I just need the best course to help become a m...  positive
# 586  can you please do a review on python 3 program...  negative
#
#      confidence interval
# 0               0.681154
# 1               0.651282
# 2               0.669800
# 3               0.517534
# 4               0.884179
# ..                   ...
# 582             0.581401
# 583             0.377692
# 584             0.674804
# 585             0.566242
# 586             0.655750
#
# [587 rows x 3 columns]

# %% [markdown]
# # Get Conclusion

# %% [markdown]
# To get the conclusion of the topic, we'll going to get the mode (the value that appears the most). But before that, we're going to remove the sentiment data that are lower than 0.5 of confidence interval. The reason is we want to remove uncertainty from the data.

# %% [markdown]
# ## Drop data that has confidence interval lower than 0.5

# %% [markdown]
# We decided to drop these data points because they indicate a low confidence level in the model's predictions (less than 0.5). Removing them ensures the dataset is cleaner and more reliable for sentiment analysis.

# %%
#df = df.drop(df[df['confidence interval'] < 0.5].index)

# %% [markdown]
# ## Re-check the data

# %%
df
# Out:
#                                                comment sentiment  \
# 0                 I’m interested in doing tech courses  positive
# 1    Not yet, there are many things I need to under...  negative
# 2     @berryberrystrawberry2428  Video explanations...  positive
# 3     @gradehacker  I'm conversational by now. I us...  positive
# 4    Was looking for data analyst related boot camp...  negative
# ..                                                 ...       ...
# 578  Hey man where I can learn python intermediate ...  positive
# 582  Hey people i want to ask you that what if i co...   neutral
# 584                      Is this course out dated now?  negative
# 585  I just need the best course to help become a m...  positive
# 586  can you please do a review on python 3 program...  negative
#
#      confidence interval
# 0               0.681154
# 1               0.651282
# 2               0.669800
# 3               0.517534
# 4               0.884179
# ..                   ...
# 578             0.634251
# 582             0.581401
# 584             0.674804
# 585             0.566242
# 586             0.655750
#
# [425 rows x 3 columns]

# %% [markdown]
# ## Get mode from the column sentiment

# %%
sentiment_table = pd.DataFrame(np.array(np.unique(df['sentiment'], return_counts = True)).transpose(), columns=['labels', 'counts'])
sentiment_table = sentiment_table.sort_values('counts', ascending = False).reset_index(drop = True)

# %% [markdown]
# Based on the table above, 421 people agree that Coursera is satisfying, 116 people feel neutral about Coursera, and 50 people agree that Coursera is not satisfying, according to the VADER algorithm, out of 587 people.
